# %% [markdown]
# <a href="https://colab.research.google.com/github/a01056549975-ui/aipro/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 첫번째 파이썬 프로그램

# %%
print("hello python")
# Out:
# hello python
